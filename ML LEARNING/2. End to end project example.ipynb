# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/soil_conditions_with_retention (1).csv')

# %%
df.head()
# Out:
#    Humidity (%) Weather Condition Soil Type  Water Level (cm)  \
# 0         59.45             Sunny      Clay             15.08
# 1         89.89             Sunny      Clay              5.70
# 2         24.12             Rainy     Silty             25.80
# 3         71.66             Windy     Loamy             35.85
# 4         30.91             Windy     Silty             28.32
#
#    Water Retention (%)
# 0                53.13
# 1                53.13
# 2                43.93
# 3                22.39
# 4                43.93

# %%
df.shape
# Out:
# (100, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Humidity (%) Weather Condition Soil Type  Water Level (cm)  \
# 0          59.45             Sunny      Clay             15.08
# 1          89.89             Sunny      Clay              5.70
# 2          24.12             Rainy     Silty             25.80
# 3          71.66             Windy     Loamy             35.85
# 4          30.91             Windy     Silty             28.32
# ..           ...               ...       ...               ...
# 95         82.77             Foggy     Peaty              6.00
# 96         55.94            Cloudy     Loamy             28.36
# 97         50.89             Foggy     Silty             19.80
# 98         49.29             Windy      Clay             20.05
# 99         62.65            Stormy      Clay             24.37
#
#     Water Retention (%)
# 0                 53.13
# 1                 53.13
# 2                 43.93
# 3                 22.39
# 4                 43.93
# ..                  ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Weather Condition'], df['Water Level (cm)'])
